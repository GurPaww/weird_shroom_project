# %%
import os
import pandas as pd
import numpy as np
import json

# %%
# class dictionary
class_dict = {
    'beginner',
    'warrior',
    'bowman',
    'thief',
    'magician',
    'pirate'
}

# %%
# job dictionary
# key = job_id

# TODO list:
# primary stat
# secondary stat
# TBD
job_dict = {
    0:{
        'job_name': 'beginner',
        'job_class': 'beginner',
        'job_race': 'explorer',
        'job_advance': 0,
        'job_path':['swordman', 'archer', 'rogue', 'magician', 'pirate']
    },
    1:{
        'job_name': 'swordman',
        'job_class': 'warrior',
        'job_race': 'explorer',
        'job_advance': 1,
        'job_path':['fighter', 'page', 'spearman']
    },
    2:{
        'job_name': 'archer',
        'job_class': 'bowman',
        'job_race': 'explorer',
        'job_advance': 1,
        'job_path':['hunter', 'crossbowman']
    },
    3:{
        'job_name': 'rogue',
        'job_class': 'thief',
        'job_race': 'explorer',
        'job_advance': 1,
        'job_path':['assasin','bandit']
    },
    4:{
        'job_name': 'magician',
        'job_class': 'magician',
        'job_race': 'explorer',
        'job_advance': 1,
        'job_path':['wizard(fire/poision)', 'wizard(ice/lightening)', 'cleric']
    },
    5:{
        'job_name': 'pirate',
        'job_class': 'pirate',
        'job_race': 'explorer',
        'job_advance': 1,
        'job_path':['brawler', 'gunslinger']
    },
}

# %%
# create json object from dictionary
json = json.dumps(job_dict)

# open file for writing, "w" 
f = open("job_dict.json","w")

# write json object to file
f.write(json)

# close file
f.close()

# %%
# f = open(os.getcwd() + "/job_dict.json")
# job_dict = json.loads(f.read())
# job_df = pd.DataFrame(job_dict)
# job_df
# Out:
#                                                        0  \
# job_name                                        beginner
# job_class                                       beginner
# job_race                                        explorer
# job_advance                                            0
# job_path     [swordman, archer, rogue, magician, pirate]
#
#                                      1                      2  \
# job_name                      swordman                 archer
# job_class                      warrior                 bowman
# job_race                      explorer               explorer
# job_advance                          1                      1
# job_path     [fighter, page, spearman]  [hunter, crossbowman]
#
#                              3  \
# job_name                 rogue
# job_class                thief
# job_race              explorer
# job_advance                  1
# job_path     [assasin, bandit]
#
# ...

# %%
# Out:
# 'Aa'
